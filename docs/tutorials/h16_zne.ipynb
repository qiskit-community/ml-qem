# %%
from qiskit import QuantumCircuit
from qiskit.compiler import transpile
from qiskit_aer import AerSimulator
from qiskit.converters import circuit_to_dag, dag_to_circuit
from qiskit_aer.noise import depolarizing_error, NoiseModel
from qiskit.quantum_info import SparsePauliOp

from qiskit.primitives import BackendEstimator

from zne import zne, ZNEStrategy
from zne.noise_amplification import *
from zne.extrapolation import *

import numpy as np
import matplotlib.pyplot as plt

import json, os, pickle, random
import numpy as np
from tqdm.notebook import tqdm
import pandas as pd

import torch
from torch.utils.data import Dataset, DataLoader, TensorDataset
from torch.optim.lr_scheduler import ReduceLROnPlateau
import torch.nn as nn

import qiskit
from qiskit import QuantumCircuit, execute
from qiskit.compiler import transpile
from qiskit_aer import AerSimulator, QasmSimulator
from qiskit.converters import circuit_to_dag, dag_to_circuit
from qiskit.quantum_info import SparsePauliOp, Operator
from qiskit.circuit.library import CXGate, RXGate, IGate, ZGate
from qiskit.providers.fake_provider import FakeMontreal, FakeLima

from blackwater.data.utils import (
    generate_random_pauli_sum_op,
    create_estimator_meas_data,
    circuit_to_graph_data_json,
    get_backend_properties_v1,
    encode_pauli_sum_op,
    create_meas_data_from_estimators
)

from mlp import MLP1, MLP2, MLP3, encode_data

from mbd_utils import cal_z_exp, generate_disorder, construct_mbl_circuit, calc_imbalance, modify_and_add_noise_to_model

import matplotlib.pyplot as plt
import seaborn as sns

# %%
backend = FakeLima()
properties = get_backend_properties_v1(backend)

## Local
backend_ideal = QasmSimulator() # Noiseless
backend_noisy = AerSimulator.from_backend(FakeLima()) # Noisy

run_config_ideal = {'shots': 10000, 'backend': backend_ideal, 'name': 'ideal'}
run_config_noisy = {'shots': 10000, 'backend': backend_noisy, 'name': 'noisy'}

# %%
def fix_random_seed(seed=0):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)  # if you are using multi-GPU.
    torch.backends.cudnn.benchmark = False
    torch.backends.cudnn.deterministic = True
    print(f'random seed fixed to {seed}')

# %%
def load_circuits(data_dir, f_ext='.json'):
    circuits = []
    ideal_exp_vals = []
    noisy_exp_vals = []
    data_files = [os.path.join(data_dir, f) for f in os.listdir(data_dir) if f.endswith(f_ext)]
    for data_file in tqdm(data_files, leave=True):
        if f_ext == '.json':
            for entry in json.load(open(data_file, 'r')):
                circuits.append(QuantumCircuit.from_qasm_str(entry['circuit']))
                ideal_exp_vals.append(entry['ideal_exp_value'])
                noisy_exp_vals.append(entry['noisy_exp_values'])
        elif f_ext == '.pk':
            for entry in pickle.load(open(data_file, 'rb')):
                circuits.append(entry['circuit'])
                ideal_exp_vals.append(entry['ideal_exp_value'])
                noisy_exp_vals.append(entry['noisy_exp_values'])
    return circuits, ideal_exp_vals, noisy_exp_vals

# %%
# train_circuits, train_ideal_exp_vals, train_noisy_exp_vals = load_circuits('./data/haoran_mbd/random_circuits/train/', '.pk')
# print(len(train_circuits))

test_circuits, test_ideal_exp_vals, test_noisy_exp_vals = load_circuits('./data/haoran_mbd/random_circuits/val/', '.pk')
print(len(test_circuits))
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# 2000

# %%
def get_zne_expval(circ,
                   obs: str,
                   extrapolator,
                   backend,
                   noise_factors = [1, 3, 5, 7],
                   amplifier=LocalFoldingAmplifier(gates_to_fold=2),
                   shots:int=10000,
                   mapping = None
                   ) -> float:
    """Returns the zero-noise expectation values for a list of observables `obs` of a circuit `circ`

    Inputs:
    obs (list[str]): Observables in Endian convention (e.g. 'IIZ' is the Z operator on the 0th qubit) for the PHYSICAL qubits
    mapping (list[int]): Mapping between logical and physical qubits, e.g. mapping[0] is the physical qubit for logical qubit 0

    """
    observable = SparsePauliOp(obs)

    ZNEEstimator = zne(BackendEstimator)
    estimator = ZNEEstimator(backend=backend)

    zne_strategy = ZNEStrategy(
        noise_factors=noise_factors,
        noise_amplifier=amplifier,
        extrapolator=extrapolator
    )

    job = estimator.run(circ, observable, shots=shots, zne_strategy=zne_strategy)
    result = job.result()
    values = result.values.tolist()

    print(values)
    print(mapping)

    if mapping is not None:
        values = [values[map] for map in mapping]

    return values

# %%
# test_circuits[0].remove_final_measurements()
# test_circuits[0].measure_active()
test_circuits[17].draw('mpl', fold=-1)

# %%
def get_measurement_qubits(qc, num_qubit):
        measurement_qubits = []
        for measurement in range(num_qubit-1, -1, -1):
            measurement_qubits.append(qc.data[-1-measurement][1][0].index)
        return measurement_qubits

# %%
k = 22
physical_qubit_list = [i for i in range(5)]
mapping = get_measurement_qubits(test_circuits[k], 4)
physical_qubit_ancilla = set(range(5)).difference(set(mapping)) # gives the physical qubit that is NOT used by any of the actual qubits, i.e. the ancilla qubit
mapping = mapping + list(physical_qubit_ancilla)
print(mapping)
# Out:
# [2, 1, 3, 0, 4]
# /var/folders/kj/mfqyg_tj77nf4gt67lvscdkw0000gn/T/ipykernel_86839/2271416955.py:4: DeprecationWarning: Back-references to from Bit instances to their containing Registers have been deprecated. Instead, inspect Registers to find their contained Bits.
#   measurement_qubits.append(qc.data[-1-measurement][1][0].index)

# %%
test_circuits[k].draw('mpl', fold=-1)

# %%
test_ideal_exp_vals[k]
# Out:
# [-0.0002, 0.1856, -0.8522, 0.8528]

# %%
# for k in [22]:
    # rc = transpile(random_circuit(4, d, 1, measure=True), backend=be, optimization_level=3)
    # print('ideal', test_ideal_exp_vals[k], 'noisy', test_noisy_exp_vals[k])
degree = 2
extrapolator = PolynomialExtrapolator(degree=degree)
mitigated = []
for obs in ['ZIIII', 'IZIII', 'IIZII', 'IIIZI', 'IIIIZ']:
    mitigated += get_zne_expval(test_circuits[k], obs, extrapolator, backend)
mitigated = mitigated[::-1]
print(mitigated)
# Out:
# [0.9686295786443785]
# None
# [-0.12746894089707417]
# None
# [-0.7996546279172649]
# None
# [0.8281301456087736]
# None
# [0.029235958273921593]
# None
# [0.029235958273921593, 0.8281301456087736, -0.7996546279172649, -0.12746894089707417, 0.9686295786443785]

# %%
mapping[]
# Out:
# [2, 1, 3, 0, 4]

# %%
[mitigated[mapping.index(i)] for i in range(5)]
# Out:
# [-0.12746894089707417,
#  0.8281301456087736,
#  0.029235958273921593,
#  -0.7996546279172649,
#  0.9686295786443785]

# %%
fix_random_seed(0)

distances = []

num_spins = 4
even_qubits = np.linspace(0, num_spins, int(num_spins/2), endpoint=False)
odd_qubits = np.linspace(1, num_spins+1, int(num_spins/2), endpoint=False)

degree = 2
extrapolator = PolynomialExtrapolator(degree=degree)
for circ, ideal, noisy in tqdm(zip(test_circuits, test_ideal_exp_vals, test_noisy_exp_vals), total=len(test_circuits)):
    out = []
    for obs in ['IIIZI', 'IIZII', 'IZIII', 'ZIIII']:
        out += get_zne_expval(test_circuits[k], obs, extrapolator, backend).values.tolist()

    ngm_mitigated = out
    imbalance_ideal = calc_imbalance([ideal], even_qubits, odd_qubits)[0]
    imbalance_noisy = calc_imbalance([noisy], even_qubits, odd_qubits)[0]
    imbalance_mitigated = calc_imbalance([ngm_mitigated], even_qubits, odd_qubits)[0]
    for q in range(4):
        ideal_q = ideal[q]
        noisy_q = noisy[q]
        ngm_mitigated_q = ngm_mitigated[q]
        distances.append({
            f"ideal_{q}": ideal_q,
            f"noisy_{q}": noisy_q,
            f"ngm_mitigated_{q}": ngm_mitigated_q,
            f"dist_noisy_{q}": np.abs(ideal_q - noisy_q),
            f"dist_mitigated_{q}": np.abs(ideal_q - ngm_mitigated_q),
            f"dist_sq_noisy_{q}": np.square(ideal_q - noisy_q),
            f"dist_sq_mitigated_{q}": np.square(ideal_q - ngm_mitigated_q),
            "imb_ideal": imbalance_ideal,
            "imb_noisy": imbalance_noisy,
            "imb_ngm": imbalance_mitigated,
            "imb_diff": imbalance_ideal - imbalance_mitigated
        })

plt.style.use({'figure.facecolor':'white'})

df = pd.DataFrame(distances)

for q in range(4):
    print(f'RMSE_noisy_{q}:', np.sqrt(df[f"dist_sq_noisy_{q}"].mean()))
    print(f'RMSE_mitigated_{q}:', np.sqrt(df[f"dist_sq_mitigated_{q}"].mean()))

print(f'RMSE_noisy:', np.sqrt(np.mean([df[f"dist_sq_noisy_{q}"].mean() for q in range(4)])))
print(f'RMSE_mitigated:', np.sqrt(np.mean([df[f"dist_sq_mitigated_{q}"].mean() for q in range(4)])))

sns.boxplot(data=df[["dist_noisy_0", "dist_mitigated_0", "dist_noisy_1", "dist_mitigated_1", "dist_noisy_2", "dist_mitigated_2", "dist_noisy_3", "dist_mitigated_3"]], orient="h", showfliers = False)
plt.title("Dist to ideal exp value")
plt.show()

sns.histplot([df['ideal_0'], df['noisy_0'], df["ngm_mitigated_0"]], kde=True, bins=40)
plt.title("Exp values distribution")
plt.show()
# Out:
# random seed fixed to 0
# 0it [00:00, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [18], in <cell line: 11>()
#      12 out = []
#      13 for obs in ['IIIZI', 'IIZII', 'IZIII', 'ZIIII']:
# ---> 14     out += get_zne_expval(test_circuits[k], obs, extrapolator, backend).values.tolist()
#      16 ngm_mitigated = out
#      17 imbalance_ideal = calc_imbalance([ideal], even_qubits, odd_qubits)[0]
#
# Input In [5], in get_zne_expval(circ, obs, extrapolator, backend, noise_factors, amplifier, shots)
#       6 estimator = ZNEEstimator(backend=backend)
#       8 zne_strategy = ZNEStrategy(
#       9     noise_factors=noise_factors,
#      10     noise_amplifier=amplifier,
#      11     extrapolator=extrapolator
#      12 )
# ---> 14 job = estimator.run(circ, observable, shots=shots, zne_strategy=zne_strategy)
#      15 result = job.result()
#      17 return result
#
# File /opt/anaconda3/envs/ngem/lib/python3.10/site-packages/qiskit/primitives/base/base_estimator.py:235, in BaseEstimator.run(self, circuits, observables, parameter_values, **run_options)
#     232 run_opts = copy(self.options)
#     233 run_opts.update_options(**run_options)
# --> 235 return self._run(
#     236     circuits,
#     237     observables,
#     238     parameter_values,
#     239     **run_opts.__dict__,
#     240 )
#
# File ~/Desktop/prototype-zne-main/zne/meta/run.py:55, in zne_run.<locals>._zne_run(self, circuits, observables, parameter_values, zne_strategy, **run_options)
#      53 target_num_experiments: int = len(circuits)
#      54 if zne_strategy.performs_noise_amplification:
# ---> 55     circuits = zne_strategy.build_noisy_circuits(circuits)
#      56     observables = zne_strategy.map_to_noisy_circuits(observables)
#      57     parameter_values = zne_strategy.map_to_noisy_circuits(parameter_values)
#
# File ~/Desktop/prototype-zne-main/zne/zne_strategy.py:208, in ZNEStrategy.build_noisy_circuits(self, original_circuits)
#     206 if isinstance(original_circuits, QuantumCircuit):
#     207     original_circuits = [original_circuits]
# --> 208 return tuple(generate_noisy_circuits(original_circuits))
#
# File ~/Desktop/prototype-zne-main/zne/zne_strategy.py:204, in ZNEStrategy.build_noisy_circuits.<locals>.generate_noisy_circuits(original_circuits)
#     202 for circuit in original_circuits:  # type: QuantumCircuit
#     203     for noise_factor in self.noise_factors:  # type: float
# --> 204         yield self.amplify_circuit_noise(circuit, noise_factor)
#
# File ~/Desktop/prototype-zne-main/zne/zne_strategy.py:181, in ZNEStrategy.amplify_circuit_noise(self, circuit, noise_factor)
#     171 """Noise amplification from :class:`~.noise_amplification.NoiseAmplifier`.
#     172
#     173 Args:
#    (...)
#     178     The noise amplified quantum circuit
#     179 """
#     180 # TODO: caching
# --> 181 return self.noise_amplifier.amplify_circuit_noise(circuit, noise_factor)
#
# File ~/Desktop/prototype-zne-main/zne/noise_amplification/folding_amplifier/local_folding_amplifier.py:154, in LocalFoldingAmplifier.amplify_circuit_noise(self, circuit, noise_factor)
#     152 noisy_circuit = circuit.copy_empty_like()
#     153 for operation, num_foldings in zip(circuit, foldings):
# --> 154     noisy_circuit = self._append_folded(noisy_circuit, operation, num_foldings)
#     155 return noisy_circuit
#
# File ~/Desktop/prototype-zne-main/zne/noise_amplification/folding_amplifier/local_folding_amplifier.py:245, in LocalFoldingAmplifier._append_folded(self, noisy_circuit, operation, num_foldings)
#     243 self._validate_num_foldings(num_foldings)
#     244 instruction, qargs, cargs = operation
# --> 245 noisy_circuit.barrier(qargs)
#     246 noisy_circuit.append(instruction, qargs, cargs)
#     247 if num_foldings > 0:
#
# File /opt/anaconda3/envs/ngem/lib/python3.10/site-packages/qiskit/circuit/quantumcircuit.py:2835, in QuantumCircuit.barrier(self, label, *qargs)
#    2832     else:
#    2833         qubits.append(qarg)
# -> 2835 return self.append(Barrier(len(qubits), label=label), qubits, [])
#
# File /opt/anaconda3/envs/ngem/lib/python3.10/site-packages/qiskit/circuit/quantumcircuit.py:1264, in QuantumCircuit.append(self, instruction, qargs, cargs)
#    1262 instructions = InstructionSet(resource_requester=requester)
#    1263 if isinstance(operation, Instruction):
# -> 1264     for qarg, carg in operation.broadcast_arguments(expanded_qargs, expanded_cargs):
#    1265         self._check_dups(qarg)
#    1266         instruction = CircuitInstruction(operation, qarg, carg)
#
# KeyboardInterrupt:
